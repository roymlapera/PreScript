# %%
import frontend
import backend
from unidecode import unidecode
import sys
import os

def resource_path(relative_path):
        """ Get absolute path to resource, works for dev and for PyInstaller 
        https://stackoverflow.com/questions/31836104/pyinstaller-and-onefile-how-to-include-an-image-in-the-exe-file"""

        try:
            # PyInstaller creates a temp folder and stores path in _MEIPASS
            base_path = sys._MEIPASS
            #base_path = sys._MEIPASS2
        except Exception:
            base_path = os.path.abspath(".")

        return os.path.join(base_path, relative_path)

def filename_creator(save_path ,patient_data_dict, prescription_dict):
    patient_ID = patient_data_dict['HC']
    patient_name = patient_data_dict['Nombres']
    patient_surname = patient_data_dict['Apellido']
    patient_presc = prescription_dict['Prescripción']

    patient_name_noaccent = unidecode(patient_name).upper()
    patient_surname_noaccent = unidecode(patient_surname).upper()
    patient_presc_noaccent = unidecode(patient_presc)

    pdfname = save_path+f'{patient_ID}_{patient_surname_noaccent}_{patient_name_noaccent}_({patient_presc_noaccent}).pdf'
    return pdfname

def main():
    # --------------------------------------------------------------------------------------------

    DEVELOP_MODE = True
    FRONTEND_QA_MODE = False
    BACKEND_QA_MODE = False

    # --------------------------------------------------------------------------------------------

    if DEVELOP_MODE:
        # Carga nuevamente las librerias para que la actualizacion del codigo se refleje al ejecutar el notebook 
        import importlib
        importlib.reload(frontend)
        importlib.reload(backend)

        # Cambia direccion de guardado para no tener limitaciones de permisos de dominio en carpeta medicos
        save_path = '//FS-201-Radioterapia.intecnus.org.ar/fisicos/8 - Físicos Médicos/Roy/INTECNUS-PreScript/'
    else:
        save_path = '//FS-201-Radioterapia.intecnus.org.ar/medicos/PRESCRIPCION/'

    # --------------------------------------------------------------------------------------------


    institution_contact = {'website': 'http://intecnus.org.ar/',
                            'email': 'contacto@intecnus.org.ar',
                            'address': 'Ruta Provincial 82 s/n-CP 8400-S.C. de Bariloche, Río Negro, Argentina',
                            'phone': 'TE: +54294 4461090'}

    path = os.path.abspath('').replace('\\', '/')
    images_path = path + '/images/'

    header_path = resource_path(images_path + 'CALIDAD.png')

    logo_path = resource_path(images_path + 'logo.png')

    watermark_path = resource_path(images_path + 'marca_agua.png')

    # Reemplazar con path a Excel de contraints actualizado
    contraints_excel_filepath = resource_path('//FS-201-Radioterapia.intecnus.org.ar/fisicos/8 - Físicos Médicos/Natalia Espector/2024 - Protocolos clínicos/Protocolo de Constraints.xlsx')

    # --------------------------------------------------------------------------------------------

    if BACKEND_QA_MODE:
        import xlstools, json

        with open("data.json", "r") as archivo:
            data_dict = json.load(archivo)

        presc_templates = xlstools.get_cell_content(file_path=contraints_excel_filepath, cell_coordinate='B2', sheet_name=None)[3:]

        for template in presc_templates:
            data_dict['Prescripción'] = template
            print(template)
            patient_data_dict, prescription_dict, targets_chart, constraints_chart = backend.prescription_importer(data_dict, contraints_excel_filepath)
            pdfname = filename_creator(save_path ,patient_data_dict, prescription_dict)
            backend.generate_print_pdf(pdfname, institution_contact, header_path, watermark_path, contraints_excel_filepath, patient_data_dict, prescription_dict, targets_chart, constraints_chart)

    else:
        app = frontend.App(contraints_excel_filepath, logo_path)
        app.mainloop()
        data_dict = app.data

        if FRONTEND_QA_MODE: 
            return
        else:
            patient_data_dict, prescription_dict, targets_chart, constraints_chart = backend.prescription_importer(data_dict, contraints_excel_filepath)
            pdfname = filename_creator(save_path ,patient_data_dict, prescription_dict)

            backend.generate_print_pdf(pdfname, institution_contact, header_path, watermark_path, contraints_excel_filepath, patient_data_dict, prescription_dict, targets_chart, constraints_chart)

        #Abro la prescripcion nueva para visualizar
        if DEVELOP_MODE:
            backend.open_pdf_with_vscode(pdfname)
        else:
            backend.open_pdf_with_chrome(pdfname)

main()
# Out:
# Saved option: PALIATIVO 20GY
# Updated presc_template to: PALIATIVO 20GY
# Updated images_template to: Portales ANT-LAT diario
# HC
# Apellido
# Nombres
# Documento
# Fecha de nacimiento
# Ciudad/País
# Fecha de admisión
# Obra social
# Medico derivante
# Guía utilizada
# Conclusiones                  Describir aquí los antecedentes clínicos del paciente.
# Plan de Tratamiento
# Técnica                       3D
# Intención                     Adyuvante
# Prescripción                  PALIATIVO 20GY
# Protocolo de Imágenes         Portales ANT-LAT diario
# Medico Tratante               Romina Ventimiglia
# Nota de Observaciones
# Tratamiento Previo            0
# Dias Alternos                 0
# Bolus                         0
# Hipoacusia                    0
# Enf. infecciosa               0
# Discap. Motora                0
# Patol. psiq./cognitiva        0
# Marcapasos                    0
# Reirradiación misma zona      0
# Sin splittear:
# ['Estructura', 'Ideal', 'Aceptable']
# ['PTV', 'V(1940 cGy) > 95 %', 'V(1900 cGy) > 95 %']
# ['', 'Dmax < 2140 cGy', 'Dmax < 2200 cGy']
# ['Tronco', 'D(0.5 cc) < 2000 cGy', 'D(2000 cc) < 15 cGy']
# ['Ojo_I', 'D(0.2 cc) < 2000 cGy', '']
# ['Ojo_D', 'D(0.2 cc) < 2000 cGy', '']
# ['Noptico_I', 'D(0.2 cc) < 2000 cGy', '']
# ['Noptico_D', 'D(0.2 cc) < 2000 cGy', '']
# ['Quiasma', 'D(0.2 cc) < 2000 cGy', '']
# ['Cristalino_I', 'Dmax < 500 cGy', '']
# ['Cristalino_D', 'Dmax < 500 cGy', '']
# ['Parotida_I', 'Dmed < 2000 cGy', '']
# ['Parotida_D', 'Dmed < 2000 cGy', '']
# ['Pulmones', 'V(2000 cGy) > 10 %', '']
# ['', 'Dmed < 800 cGy', '']
# ['Esofago', 'Dmax < 2000 cGy', '']
# ['Traquea', 'Dmax < 2000 cGy', '']
# ['Corazon', 'Dmax < 2000 cGy', '']
# ['', 'Dmed < 1000 cGy', '']
# ['Rinon_I', 'V(1500 cGy) > 35 %', '']
# ['', 'Dmed < 1000 cGy', '']
# ['Rinon_D', 'V(1500 cGy) > 35 %', '']
# ['', 'Dmed < 1000 cGy', '']
# ['Estomago', 'Dmax < 2000 cGy', '']
# ['Higado', 'Dmed < 1500 cGy', '']
# ['']
# ['Intestinos', 'Dmax < 2000 cGy', '']
# ['Recto', 'Dmax < 2000 cGy', '']
# ['Vejiga', 'Dmax < 2000 cGy', '']
# ['Genitales', 'Dmax < 2000 cGy', '']
# ['Cauda_Equina', 'Dmax < 2500 cGy', '']
# 30
# ['Estructura', 'Ideal', 'Aceptable']
# ['PTV', 'V(1940 cGy) > 95 %', 'V(1900 cGy) > 95 %']
# ['', 'Dmax < 2140 cGy', 'Dmax < 2200 cGy']
# ['Tronco', 'D(0.5 cc) < 2000 cGy', 'D(2000 cc) < 15 cGy']
# ['Ojo_I', 'D(0.2 cc) < 2000 cGy', '']
# ['Ojo_D', 'D(0.2 cc) < 2000 cGy', '']
# ['Noptico_I', 'D(0.2 cc) < 2000 cGy', '']
# ['Noptico_D', 'D(0.2 cc) < 2000 cGy', '']
# ['Quiasma', 'D(0.2 cc) < 2000 cGy', '']
# ['Cristalino_I', 'Dmax < 500 cGy', '']
# ['Cristalino_D', 'Dmax < 500 cGy', '']
# ['Parotida_I', 'Dmed < 2000 cGy', '']
# ['Parotida_D', 'Dmed < 2000 cGy', '']
# ['Pulmones', 'V(2000 cGy) > 10 %', '']
# ['', 'Dmed < 800 cGy', '']
# ['Esofago', 'Dmax < 2000 cGy', '']
#
#
# ['Estructura', 'Ideal', 'Aceptable']
# ['Traquea', 'Dmax < 2000 cGy', '']
# ['Corazon', 'Dmax < 2000 cGy', '']
# ['', 'Dmed < 1000 cGy', '']
# ['Rinon_I', 'V(1500 cGy) > 35 %', '']
# ['', 'Dmed < 1000 cGy', '']
# ['Rinon_D', 'V(1500 cGy) > 35 %', '']
# ['', 'Dmed < 1000 cGy', '']
# ['Estomago', 'Dmax < 2000 cGy', '']
# ['Higado', 'Dmed < 1500 cGy', '']
# ['']
# ['Intestinos', 'Dmax < 2000 cGy', '']
# ['Recto', 'Dmax < 2000 cGy', '']
# ['Vejiga', 'Dmax < 2000 cGy', '']
# ['Genitales', 'Dmax < 2000 cGy', '']
# ['Cauda_Equina', 'Dmax < 2500 cGy', '']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 109
#     106         else:
#     107             backend.open_pdf_with_chrome(pdfname)
# --> 109 main()
#
# Cell In[1], line 101, in main()
#      98     patient_data_dict, prescription_dict, targets_chart, constraints_chart = backend.prescription_importer(data_dict, contraints_excel_filepath)
#      99     pdfname = filename_creator(save_path ,patient_data_dict, prescription_dict)
# --> 101     backend.generate_print_pdf(pdfname, institution_contact, header_path, watermark_path, contraints_excel_filepath, patient_data_dict, prescription_dict, targets_chart, constraints_chart)
#     103 #Abro la prescripcion nueva para visualizar
#     104 if DEVELOP_MODE:
#
# File p:\8 - Físicos Médicos\Roy\INTECNUS-PreScript\backend.py:394, in generate_print_pdf(pdfname, institution_contact, image_path, watermark_path, contraints_excel_filepath, patient_data_dict, prescription_dict, targets_chart, constraints_chart)
#     391 presc_title = Paragraph('RESTRICCIONES', styles['PDFTitle'])
#     392 story.append(presc_title)
# --> 394 constraints_chart = constraints_chart_splitter(constraints_chart)
#     396 # Create a table from the data
#     397 constraints_table = Table(constraints_chart, colWidths=constraints_col_widths)
#
# File p:\8 - Físicos Médicos\Roy\INTECNUS-PreScript\backend.py:275, in constraints_chart_splitter(constraints_chart)
#     272 for line in second_part: print(line)
#     274 content = []
# --> 275 for (value1, value2, value3), (value4, value5, value6) in zip(first_part,second_part):
#     276     content.append([value1, value2, value3, value4, value5, value6])
#     278 print('Splitteado:')
#
# ValueError: not enough values to unpack (expected 3, got 1)
